# %%
 cd /content/drive/MyDrive/Ayush_Gupta/video_summarise
# Out:
# /content/drive/MyDrive/Ayush_Gupta/video_summarise

# %%
# !git clone https://github.com/aashay15/Extractive-Video-Text-Summarizer.git

# %%
cd /content/drive/MyDrive/Ayush_Gupta/video_summarise/Extractive-Video-Text-Summarizer
# Out:
# /content/drive/MyDrive/Ayush_Gupta/video_summarise/Extractive-Video-Text-Summarizer

# %%
# !pip install youtube-dl
# !pip install pysrt
# !pip install sumy
# Out:
# ...
#      |████████████████████████████████| 1.9MB 13.0MB/s
# ...
#      |████████████████████████████████| 112kB 13.1MB/s
# ...
#   Created wheel for pysrt: filename=pysrt-1.1.2-cp37-none-any.whl size=13427 sha256=046288a1479d2a725dea6a09bfff178f261600e7351296b2923eb938bfdc8d1e
#   Stored in directory: /root/.cache/pip/wheels/57/7d/68/0307a3018abbaa1a7b870e6419123d07480dd169bfdea74aea
# Successfully built pysrt
# ...
#      |████████████████████████████████| 92kB 6.8MB/s
# ...
#      |████████████████████████████████| 10.1MB 26.1MB/s
# ...
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21680 sha256=a299122a45b52d9cd3d78b5d9f2cc57d1dd3f7d7347bff588b6b026fef3704f5
#   Stored in directory: /root/.cache/pip/wheels/5a/4d/a1/510b12c5e65e0b2b3ce539b2af66da0fc57571e528924f4a52
# ...
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746863 sha256=e930e134ccf46a57a8e53cf0bd8ff16ba642daa8c0ea934e0ef9afa01cb7a12c
# ...

# %%
# !python /content/drive/MyDrive/Ayush_Gupta/video_summarise/Extractive-Video-Text-Summarizer/TextSummary.py

# %%
# !python /content/drive/MyDrive/Ayush_Gupta/video_summarise/Extractive-Video-Text-Summarizer/Summarizer.py
# Out:
# text 6815
# On February 9, 2014, The New York Times reported that Wikipedia has 18 billion page views and nearly 500 million unique visitors a month, "according to the ratings firm comScore".[46] Loveland and Reagle argue that, in process, Wikipedia follows a long tradition of historical encyclopedias that accumulated improvements piecemeal through "stigmergic accumulation".[47][48]
#
#
#
# ...

# %%
# !python /content/drive/MyDrive/Ayush_Gupta/video_summarise/Extractive-Video-Text-Summarizer/YoutubeDownload.py
# Out:
# [youtube] rbasThWVb-c: Downloading webpage
# WARNING: No subtitle format found matching "srt" for language en, using vtt
# [info] Writing video subtitles to: 1.en.vtt
# [download] 1.mp4 has already been downloaded
# [download] 100% of 9.23MiB

# %%
# !python /content/drive/MyDrive/Ayush_Gupta/video_summarise/Extractive-Video-Text-Summarizer/VideoSummarizer.py
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [(7.16, 7.17), (7.17, 8.839), (29.359, 29.369), (29.369, 31.189), (50.779, 50.789), (69.56, 69.57), (85.67, 85.68), (85.68, 90.41), (97.76, 97.77), (108.92, 108.93), (108.93, 111.42), (180.479, 180.489), (185.89, 188.64), (188.64, 188.65), (210.42, 210.43), (210.43, 214.77), (214.77, 214.78), (214.78, 217.41), (217.41, 217.42), (217.42, 219.96), (219.96, 219.97), (232.399, 232.409), (232.409, 235.009), (235.009, 235.019), (244.43, 244.44), (244.44, 253.61), (253.61, 253.62), (253.62, 254.83), (254.83, 254.84), (254.84, 258.289), (258.289, 258.299), (258.299, 260.509), (260.509, 260.519), (260.519, 263.779), (275.34, 279.83), (279.83, 279.84), (312.71, 312.72), (336.77, 336.78), (336.78, 337.25), (337.25, 337.26)]
# Traceback (most recent call last):
# ...
