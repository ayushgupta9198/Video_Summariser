# %%
cd /content/drive/MyDrive/Ayush_Gupta/video_summarise
# Out:
# /content/drive/MyDrive/Ayush_Gupta/video_summarise

# %%
# !git clone https://github.com/Omodaka9375/YouTube-Video-Summarizer.git

# %%
cd /content/drive/MyDrive/Ayush_Gupta/video_summarise/YouTube-Video-Summarizer
# Out:
# /content/drive/MyDrive/Ayush_Gupta/video_summarise/YouTube-Video-Summarizer

# %%
# !pip install -r requirements.txt
# Out:
# ...
#      |████████████████████████████████| 31.8MB 164kB/s
# ...
#      |████████████████████████████████| 92kB 10.7MB/s
# ...
#      |████████████████████████████████| 1.8MB 39.5MB/s
# ...
#      |████████████████████████████████| 10.1MB 17.9MB/s
# ...
#   Created wheel for ffmpeg: filename=ffmpeg-1.4-cp37-none-any.whl size=6083 sha256=1071a81c96d46935ac8d5853958496b72b0f56bd82f1df732daa4699b3538ef1
#   Stored in directory: /root/.cache/pip/wheels/b6/68/c3/a05a35f647ba871e5572b9bbfc0b95fd1c6637a2219f959e7a
# ...
#   Created wheel for pycountry: filename=pycountry-20.7.3-py2.py3-none-any.whl size=10746863 sha256=4c80318925fbaf518ad165fa756a480536d07336b7d724a23ed44ddd90a82ca4
#   Stored in directory: /root/.cache/pip/wheels/33/4e/a6/be297e6b83567e537bed9df4a93f8590ec01c1acfbcd405348
# ...
#   Created wheel for breadability: filename=breadability-0.1.20-py2.py3-none-any.whl size=21680 sha256=37bf5e1f8063a8493cb92e814967a72aeec4fbc54d75866bce5fe541f50e9319
# ...

# %%
# !pip install -U youtube-dl
# !sudo apt purge youtube-dl 
# !sudo pip3 install youtube-dl
# Out:
# ...
#      |████████████████████████████████| 1.9MB 4.3MB/s
# ...
#   Found existing installation: youtube-dl 2020.3.8
#     Uninstalling youtube-dl-2020.3.8:
#       Successfully uninstalled youtube-dl-2020.3.8
# ...
# Reading package lists... Done
# Building dependency tree
# Reading state information... Done
# Package 'youtube-dl' is not installed, so not removed
# 0 upgraded, 0 newly installed, 0 to remove and 29 not upgraded.
# ...

# %%
# !sudo apt-get install -qq python python-dev python-pip build-essential swig libpulse-dev

# %%
! pip install PocketSphinx
# Out:
# ...
#      |████████████████████████████████| 29.1MB 176kB/s
# ...
#   Created wheel for PocketSphinx: filename=pocketsphinx-0.1.15-cp37-cp37m-linux_x86_64.whl size=30127515 sha256=1685ca562e7cab51aad9e919c5c8a21fde9e1f2dba157ee33708bd693c7d3346
#   Stored in directory: /root/.cache/pip/wheels/52/fd/52/2f62c9a0036940cc0c89e58ee0b9d00fcf78243aeaf416265f
# Successfully built PocketSphinx
# ...

# %%
import nltk
nltk.download('punkt')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Unzipping tokenizers/punkt.zip.
# True

# %%
# !python summarize.py https://youtu.be/fgdIkPXMNyA
# Out:
# [youtube] fgdIkPXMNyA: Downloading webpage
# [download] Destination: American Morning - AM One Minute News for Nov. 1, 2011.webm
# [download] 100% of 1.36MiB in 00:00
# [ffmpeg] Destination: American Morning - AM One Minute News for Nov. 1, 2011.wav
# Deleting original file American Morning - AM One Minute News for Nov. 1, 2011.webm (pass -k to keep)
#
# Transcribing audio...
#
# Recognized text:
# ...

# %%
# !python /content/drive/MyDrive/Ayush_Gupta/video_summarise/YouTube-Video-Summarizer/text_summarise.py
# Out:
# 2021-03-03 11:14:08.788732: I tensorflow/stream_executor/platform/default/dso_loader.cc:49] Successfully opened dynamic library libcudart.so.11.0
# Downloading: 100% 792k/792k [00:00<00:00, 1.78MB/s]
# original text preprocessed:
# ...

# %%
|
